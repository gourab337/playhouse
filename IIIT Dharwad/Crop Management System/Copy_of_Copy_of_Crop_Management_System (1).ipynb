# %%
# Project by Sanchit Goel[19BCS095], Gourab Chakraborty[19BEC014], Saurav Bhagat[19BCS103] IIIT Dharwad.

import pandas as pd
import re
import matplotlib.pyplot as plt
import sys
from getpass import getpass

# %%
# ADMIN USERNAME: admin
# ADMIN PASSWORD: password


class User:
    def __init__(self, fname, lname):
      self.firstname = fname
      self.lastname = lname

    def getUsername(self):
      #print(self.firstname, self.lastname)
      print("Enter Username:")
      self.username=input()
    def getPassword(self):
      self.password = getpass("Enter Password:")
      User.password=self.password
      User.username=self.username
      print("****************User Registered******************")

# %%
response = int(input("ADMIN(1) |  USER(2)?"))

if(response is 2):
  fname=input("Enter First Name:")
  lname=input("Enter Last Name:")
  x = User(fname, lname)
  x.getUsername()
  x.getPassword()
  response = 3
# Out:
# ADMIN(1) |  USER(2)?2
# Enter First Name:sanchit
# Enter Last Name:goel
# Enter Username:
# sanchman
# Enter Password:··········
# ****************User Registered******************

# %%
class Login:
    def __init__(self, username, password):
        self.username = username
        self.password = password
     
        Login.username=self.username
        Login.password=self.password
        Login.token=0
        #Login.AdminAccess=False
        if((User.username == Login.username) and (User.password == Login.password)):
            print("Login Successful!")
            Login.token=1
        else:
            print("Login Failed!")
            Login.token=0
        Login.token=self.token

# %%
def bar(f):
    plt.figure(figsize = (10,5))
    plt.bar(f['Crop_Year'],f['Production'])
                 #set label
    plt.title('Crop Production Details', fontweight = 'bold')
    plt.xticks([1998, 2000, 2002, 2004, 2006, 2008])
    plt.xlabel('Crop Year')
    plt.ylabel('Production')
    plt.show()

def box(f):
    plt.figure(figsize = (10,5))
    years = []
    for i in range(1997, 2009):
        years.append(f.loc[f.Crop_Year == i]['Production'])
    labels = ['1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008']
    plt.boxplot(years, labels = labels)
    plt.title('Crop Production Details', fontweight = 'bold')
    plt.show()

def line(f):
    plt.figure(figsize = (10,5))
    plt.plot(f['Crop_Year'],f['Production'])
          #set label
    plt.ylabel('Production')
    plt.xlabel('Crop_Year')
    plt.xticks([1998, 2000, 2002, 2004, 2006,2008])
    plt.title('Crop Production Details', fontweight = 'bold')
    plt.show()

# %%
print(response)
if(response is 1):
  uname=input("Enter Username:\n")
  pword= getpass("Enter Password:\n")
if((uname == "admin" ) and (pword == "password")):
  print("Login Successful!")
else:
  print("Login Unsuccessful")
  exit()
# Out:
# 3
# Login Successful!

# %%
#class Productivity_Details:
  def TokenCheck(token):
    print(Login.token)
    if(Login.token == 1): # and (Login.AdminAccess == False)):
      ans=input("DO you want to see the graph (Y/N):")
      if(ans=='Y'):
          print ("The graph of productivity vs crop year")
          types = ['Line', 'Bar', 'Box and Whiskers']
          num = 1,2,3
          for i, j in zip(num, types):
            print("Press " + str(i) + " for " + j + " graph." )
          no = int(input())
          print("Select the crop")
          print("For Arecanut click 1")
          print("For Other kharif click 2") 
          print("For Rice  click 3")
          print("For Banana click 4")
          print("For Cashewnut click 5")
          print("For Cocunut click 6")
          n=int(input())
          if(n==1):
           #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet2')
          #set plot  
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f)
          elif(n==2):
               #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet3')
                #set plot 
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f) 
          elif(n==3):
                #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet4')
                  #set plot 
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f)   
          elif(n==4):
             #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet5')
                  #set plot  
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f)
          elif(n==5):
              #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet6')
               #set plot   
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f) 
          elif(n==6):
                    #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet7')
                  #set plot  
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f)
      path1 = "CropsDataFile.xlsx"
      cropdata = pd.read_excel(path1)
      columns_titles = ["Crop_Year","Crop","State_Name","District_Name","Season","Production","Area"]
      cropdata=cropdata.reindex(columns=columns_titles)
      answ = input("Do you want to see the full data?")
      if ((answ == 'YES') or (answ == 'yes') or (answ == 'Y') or (answ == 'y')):
              pd.set_option('display.max_rows', None)
              pd.set_option('display.max_columns', None)
              pd.set_option('display.width', None)
              pd.set_option('display.max_colwidth', -1)
              print(cropdata)
      cropdata.to_excel("Newformatdata.xlsx")
      ans = input("do you want to search for specific details?")
      if ans == 'yes':
        cropdata.reset_index(drop=True)
        year = int(input("Enter the year: "))
        print(cropdata.loc[cropdata['Crop_Year'] == year]['Crop'])
        crop = input("Enter the crop name: ")
        print(cropdata.loc[(cropdata['Crop'] == crop) & (cropdata['Crop_Year'] == year)]['State_Name'])
        state = input("Enter the state name: ")
        print(cropdata.loc[
                  (cropdata['State_Name'] == state) & (cropdata['Crop'] == crop) & (cropdata['Crop_Year'] == year)][
                  'District_Name'])
        district = input("Enter the district name: ")
        print('This is the amount of production of ' + crop + ' in the year ' + str(
            year) + ' in ' + state + ', ' + district)
        print(cropdata.loc[(cropdata['District_Name'] == district) & (cropdata['State_Name'] == state) & (
                    cropdata['Crop'] == crop) & (cropdata['Crop_Year'] == year)])


    #if (Login.token == 2): #and (Login.AdminAccess == True)):

# %%
path1 = "CropsDataFile.xlsx"
cropdata = pd.read_excel(path1)
if(response == 1):
      answer = input("Do you want to insert more details?")
      if (answer == "yes"):
        statename = input("Enter the statename: ")
        districtname = input("Enter the district name: ")
        cropyear = input("Enter the crop year: ")
        season = input("Enter the season: ")
        crop = input("Enter the crop: ")
        area = input("Enter the area: ")
        production = input("Enter the production amount: ")
        new_row = {'State_Name': statename, 'District_Name': districtname, 'Crop_Year': cropyear, 'Season': season, 'Crop': crop, 'Area': area, 'Production': production}
        cropdata = cropdata.append(new_row, ignore_index=True)
        print("This is the new data frame after appending the details that you entered:")
        print(cropdata)
else:        
      ans=input("DO you want to see the graph (Y/N):")
      if((ans=='Y') or (ans =='y')):
          print ("The graph of productivity vs crop year")
          types = ['Line', 'Bar', 'Box and Whiskers']
          num = 1,2,3
          for i, j in zip(num, types):
            print("Press " + str(i) + " for " + j + " graph." )
          no = int(input())
          print("Select the crop")
          print("For Arecanut click 1")
          print("For Other kharif click 2") 
          print("For Rice  click 3")
          print("For Banana click 4")
          print("For Cashewnut click 5")
          print("For Cocunut click 6")
          n=int(input())
          if(n==1):
           #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet2')
          #set plot  
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f)
          elif(n==2):
               #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet3')
                #set plot 
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f) 
          elif(n==3):
                #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet4')
                  #set plot 
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f)   
          elif(n==4):
             #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet5')
                  #set plot  
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f)
          elif(n==5):
              #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet6')
               #set plot   
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f) 
          elif(n==6):
                    #set directory
              f=pd.read_excel(r'file1.xlsx','Sheet7')
                  #set plot  
              if no == 1:
                  line(f)
              elif no == 2:
                  bar(f)
              elif no == 3:
                  box(f)
          columns_titles = ["Crop_Year","Crop","State_Name","District_Name","Season","Production"]
          cropdata=cropdata.reindex(columns=columns_titles)
      answ = input("Do you want to see the full data?")
      if ((answ == 'YES') or (answ == 'yes') or (answ == 'Yes') or (answ == 'Y') or (answ == 'y')):
              pd.set_option('display.max_rows', None)
              pd.set_option('display.width', None)
              pd.set_option('display.max_colwidth', -1)
              print(cropdata)
              cropdata.to_excel("Newformatdata.xlsx")
      ans = input("do you want to search for specific details?")
      if ans == 'yes':
            cropdata.reset_index(drop=True)
            year = int(input("Enter the year: "))
            print(cropdata.loc[cropdata['Crop_Year'] == year]['Crop'])
            crop = input("Enter the crop name: ")
            print(cropdata.loc[(cropdata['Crop'] == crop) & (cropdata['Crop_Year'] == year)]['State_Name'])
            state = input("Enter the state name: ")
            print(cropdata.loc[(cropdata['State_Name'] == state) & (cropdata['Crop'] == crop) & (cropdata['Crop_Year'] == year)]['District_Name'])
            district = input("Enter the district name: ")
            print('This is the amount of production of ' + crop + ' in the year ' + str(year) + ' in ' + state + ', ' + district)
            print(cropdata.loc[(cropdata['District_Name'] == district) & (cropdata['State_Name'] == state) & (cropdata['Crop'] == crop) & (cropdata['Crop_Year'] == year)])
# Out:
# DO you want to see the graph (Y/N):Y
# The graph of productivity vs crop year
# Press 1 for Line graph.
# Press 2 for Bar graph.
# Press 3 for Box and Whiskers graph.
# 2
# Select the crop
# For Arecanut click 1
# For Other kharif click 2
# For Rice  click 3
# For Banana click 4
# For Cashewnut click 5
# For Cocunut click 6
# 3
# Do you want to see the full data?yes
#      Crop_Year                 Crop                   State_Name  \
# 0    2000       Arecanut             Andaman and Nicobar Islands
# 1    2000       Other Kharif pulses  Andaman and Nicobar Islands
# 2    2000       Rice                 Andaman and Nicobar Islands
# 3    2000       Banana               Andaman and Nicobar Islands
# 4    2000       Cashewnut            Andaman and Nicobar Islands
# 5    2000       Coconut              Andaman and Nicobar Islands
# 6    2000       Dry ginger           Andaman and Nicobar Islands
# 7    2000       Sugarcane            Andaman and Nicobar Islands
# 8    2000       Sweet potato         Andaman and Nicobar Islands
# 9    2000       Tapioca              Andaman and Nicobar Islands
# 10   2001       Arecanut             Andaman and Nicobar Islands
# 11   2001       Other Kharif pulses  Andaman and Nicobar Islands
# 12   2001       Rice                 Andaman and Nicobar Islands
# 13   2001       Cashewnut            Andaman and Nicobar Islands
# 14   2001       Coconut              Andaman and Nicobar Islands
# 15   2001       Dry ginger           Andaman and Nicobar Islands
# 16   2001       Sugarcane            Andaman and Nicobar Islands
# 17   2001       Sweet potato         Andaman and Nicobar Islands
# 18   2002       Rice                 Andaman and Nicobar Islands
# 19   2002       Arecanut             Andaman and Nicobar Islands
# 20   2002       Banana               Andaman and Nicobar Islands
# 21   2002       Black pepper         Andaman and Nicobar Islands
# 22   2002       Cashewnut            Andaman and Nicobar Islands
# 23   2002       Coconut              Andaman and Nicobar Islands
# 24   2002       Dry chillies         Andaman and Nicobar Islands
# 25   2002       Dry ginger           Andaman and Nicobar Islands
# 26   2002       Sugarcane            Andaman and Nicobar Islands
# 27   2003       Rice                 Andaman and Nicobar Islands
# 28   2003       Arecanut             Andaman and Nicobar Islands
# 29   2003       Banana               Andaman and Nicobar Islands
# 30   2003       Black pepper         Andaman and Nicobar Islands
# 31   2003       Cashewnut            Andaman and Nicobar Islands
# 32   2003       Coconut              Andaman and Nicobar Islands
# 33   2003       Dry chillies         Andaman and Nicobar Islands
# 34   2003       Dry ginger           Andaman and Nicobar Islands
# 35   2003       other oilseeds       Andaman and Nicobar Islands
# 36   2004       Rice                 Andaman and Nicobar Islands
# 37   2004       Arecanut             Andaman and Nicobar Islands
# 38   2004       Banana               Andaman and Nicobar Islands
# 39   2004       Black pepper         Andaman and Nicobar Islands
# 40   2004       Cashewnut            Andaman and Nicobar Islands
# 41   2004       Coconut              Andaman and Nicobar Islands
# 42   2004       Dry chillies         Andaman and Nicobar Islands
# 43   2004       Dry ginger           Andaman and Nicobar Islands
# 44   2004       other oilseeds       Andaman and Nicobar Islands
# 45   2005       Rice                 Andaman and Nicobar Islands
# 46   2005       Arecanut             Andaman and Nicobar Islands
# 47   2005       Banana               Andaman and Nicobar Islands
# 48   2005       Black pepper         Andaman and Nicobar Islands
# 49   2005       Cashewnut            Andaman and Nicobar Islands
# 50   2005       Coconut              Andaman and Nicobar Islands
# 51   2005       Dry chillies         Andaman and Nicobar Islands
# 52   2005       Turmeric             Andaman and Nicobar Islands
# 53   2006       Arecanut             Andaman and Nicobar Islands
# 54   2006       Banana               Andaman and Nicobar Islands
# 55   2006       Black pepper         Andaman and Nicobar Islands
# 56   2006       Cashewnut            Andaman and Nicobar Islands
# 57   2006       Coconut              Andaman and Nicobar Islands
# 58   2006       Dry chillies         Andaman and Nicobar Islands
# 59   2006       Dry ginger           Andaman and Nicobar Islands
# 60   2006       Sugarcane            Andaman and Nicobar Islands
# 61   2006       Sweet potato         Andaman and Nicobar Islands
# 62   2006       Tapioca              Andaman and Nicobar Islands
# 63   2006       Turmeric             Andaman and Nicobar Islands
# 64   2010       Rice                 Andaman and Nicobar Islands
# 65   2010       Sugarcane            Andaman and Nicobar Islands
# 66   2010       Arecanut             Andaman and Nicobar Islands
# 67   2010       Black pepper         Andaman and Nicobar Islands
# 68   2010       Cashewnut            Andaman and Nicobar Islands
# 69   2010       Dry chillies         Andaman and Nicobar Islands
# 70   2010       Dry ginger           Andaman and Nicobar Islands
# 71   2010       Maize                Andaman and Nicobar Islands
# 72   2010       Moong(Green Gram)    Andaman and Nicobar Islands
# 73   2010       Sweet potato         Andaman and Nicobar Islands
# 74   2010       Turmeric             Andaman and Nicobar Islands
# 75   2010       Urad                 Andaman and Nicobar Islands
# 76   2010       Banana               Andaman and Nicobar Islands
# 77   2010       Coconut              Andaman and Nicobar Islands
# 78   2010       Tapioca              Andaman and Nicobar Islands
# 79   2000       Arecanut             Andaman and Nicobar Islands
# 80   2000       Other Kharif pulses  Andaman and Nicobar Islands
# 81   2000       Rice                 Andaman and Nicobar Islands
# 82   2000       Banana               Andaman and Nicobar Islands
# 83   2000       Cashewnut            Andaman and Nicobar Islands
# 84   2000       Coconut              Andaman and Nicobar Islands
# 85   2000       Dry ginger           Andaman and Nicobar Islands
# 86   2000       other oilseeds       Andaman and Nicobar Islands
# 87   2000       Sugarcane            Andaman and Nicobar Islands
# 88   2000       Sweet potato         Andaman and Nicobar Islands
# 89   2000       Tapioca              Andaman and Nicobar Islands
# 90   2001       Arecanut             Andaman and Nicobar Islands
# 91   2001       Other Kharif pulses  Andaman and Nicobar Islands
# 92   2001       Rice                 Andaman and Nicobar Islands
# 93   2001       Cashewnut            Andaman and Nicobar Islands
# 94   2001       Coconut              Andaman and Nicobar Islands
# 95   2001       Dry ginger           Andaman and Nicobar Islands
# 96   2001       Sugarcane            Andaman and Nicobar Islands
# 97   2001       Sweet potato         Andaman and Nicobar Islands
# 98   2006       Rice                 Andaman and Nicobar Islands
# 99   2006       Arecanut             Andaman and Nicobar Islands
# 100  2006       Banana               Andaman and Nicobar Islands
# 101  2006       Black pepper         Andaman and Nicobar Islands
# 102  2006       Cashewnut            Andaman and Nicobar Islands
# 103  2006       Coconut              Andaman and Nicobar Islands
# 104  2006       Dry chillies         Andaman and Nicobar Islands
# 105  2006       Dry ginger           Andaman and Nicobar Islands
# 106  2006       other oilseeds       Andaman and Nicobar Islands
# 107  2006       Sugarcane            Andaman and Nicobar Islands
# 108  2006       Sweet potato         Andaman and Nicobar Islands
# 109  2006       Tapioca              Andaman and Nicobar Islands
# 110  2006       Turmeric             Andaman and Nicobar Islands
# 111  2010       Rice                 Andaman and Nicobar Islands
# 112  2010       Sugarcane            Andaman and Nicobar Islands
# 113  2010       Arecanut             Andaman and Nicobar Islands
# 114  2010       Arhar/Tur            Andaman and Nicobar Islands
# 115  2010       Black pepper         Andaman and Nicobar Islands
# 116  2010       Cashewnut            Andaman and Nicobar Islands
# 117  2010       Dry chillies         Andaman and Nicobar Islands
# 118  2010       Dry ginger           Andaman and Nicobar Islands
# 119  2010       Groundnut            Andaman and Nicobar Islands
# 120  2010       Maize                Andaman and Nicobar Islands
# 121  2010       Moong(Green Gram)    Andaman and Nicobar Islands
# 122  2010       Sunflower            Andaman and Nicobar Islands
# 123  2010       Sweet potato         Andaman and Nicobar Islands
# 124  2010       Turmeric             Andaman and Nicobar Islands
# 125  2010       Urad                 Andaman and Nicobar Islands
# 126  2010       Banana               Andaman and Nicobar Islands
# 127  2010       Coconut              Andaman and Nicobar Islands
# 128  2010       Tapioca              Andaman and Nicobar Islands
# 129  2002       Rice                 Andaman and Nicobar Islands
# 130  2002       Arecanut             Andaman and Nicobar Islands
# 131  2002       Banana               Andaman and Nicobar Islands
# 132  2002       Black pepper         Andaman and Nicobar Islands
# 19   NICOBARS                  Whole Year   2083.00
# 20   NICOBARS                  Whole Year   1278.00
# 21   NICOBARS                  Whole Year   13.50
# 22   NICOBARS                  Whole Year   208.00
# 23   NICOBARS                  Whole Year   67490000.00
# 24   NICOBARS                  Whole Year   28.80
# 25   NICOBARS                  Whole Year   133.00
# 26   NICOBARS                  Whole Year   40.00
# 27   NICOBARS                  Kharif       90.17
# 28   NICOBARS                  Whole Year   1525.00
# 29   NICOBARS                  Whole Year   1763.00
# 30   NICOBARS                  Whole Year   15.86
# 31   NICOBARS                  Whole Year   208.50
# 32   NICOBARS                  Whole Year   68580000.00
# 33   NICOBARS                  Whole Year   102.00
# 34   NICOBARS                  Whole Year   326.40
# 35   NICOBARS                  Whole Year   0.30
# 36   NICOBARS                  Kharif       72.57
# 37   NICOBARS                  Whole Year   805.85
# 38   NICOBARS                  Whole Year   404.12
# 39   NICOBARS                  Whole Year   15.86
# 40   NICOBARS                  Whole Year   197.90
# 41   NICOBARS                  Whole Year   52380000.00
# 42   NICOBARS                  Whole Year   145.20
# 43   NICOBARS                  Whole Year   366.00
# 44   NICOBARS                  Whole Year   0.11
# 45   NICOBARS                  Kharif       12.06
# 46   NICOBARS                  Whole Year  NaN
# 47   NICOBARS                  Whole Year   582.00
# 48   NICOBARS                  Whole Year   0.10
# 49   NICOBARS                  Whole Year   55.80
# 50   NICOBARS                  Whole Year   52030000.00
# 51   NICOBARS                  Whole Year  NaN
# 52   NICOBARS                  Whole Year   70.00
# 53   NICOBARS                  Whole Year   477.60
# 54   NICOBARS                  Whole Year   976.00
# 55   NICOBARS                  Whole Year   0.68
# 56   NICOBARS                  Whole Year   85.13
# 57   NICOBARS                  Whole Year   59370000.00
# 58   NICOBARS                  Whole Year   9.00
# 59   NICOBARS                  Whole Year   21.00
# 60   NICOBARS                  Whole Year   0.50
# 61   NICOBARS                  Whole Year   86.00
# 62   NICOBARS                  Whole Year   450.00
# 63   NICOBARS                  Whole Year   1.03
# 64   NICOBARS                  Autumn       10.00
# 65   NICOBARS                  Autumn       41.75
# 66   NICOBARS                  Rabi         1610.00
# 67   NICOBARS                  Rabi         8.50
# 68   NICOBARS                  Rabi         260.50
# 69   NICOBARS                  Rabi         25.00
# 70   NICOBARS                  Rabi         9.64
# 71   NICOBARS                  Rabi         18.22
# 72   NICOBARS                  Rabi         1.10
# 73   NICOBARS                  Rabi         208.00
# 74   NICOBARS                  Rabi         0.50
# 75   NICOBARS                  Rabi         1.16
# 76   NICOBARS                  Whole Year   3425.00
# 77   NICOBARS                  Whole Year   71300000.00
# 78   NICOBARS                  Whole Year   575.00
# 79   NORTH AND MIDDLE ANDAMAN  Kharif       5200.00
# 80   NORTH AND MIDDLE ANDAMAN  Kharif       448.00
# 81   NORTH AND MIDDLE ANDAMAN  Kharif       31863.00
# 82   NORTH AND MIDDLE ANDAMAN  Whole Year   12073.00
# 83   NORTH AND MIDDLE ANDAMAN  Whole Year   54.00
# 184  SOUTH ANDAMANS            Whole Year   60.00
# 185  SOUTH ANDAMANS            Autumn       3788.00
# 186  SOUTH ANDAMANS            Autumn       402.00
# 187  SOUTH ANDAMANS            Rabi         1900.00
# 188  SOUTH ANDAMANS            Rabi         13.20
# 189  SOUTH ANDAMANS            Rabi         98.00
# 190  SOUTH ANDAMANS            Rabi         10.50
# 191  SOUTH ANDAMANS            Rabi         148.00
# 192  SOUTH ANDAMANS            Rabi         828.52
# 193  SOUTH ANDAMANS            Rabi         7.60
# 194  SOUTH ANDAMANS            Rabi         253.00
# 195  SOUTH ANDAMANS            Rabi         17.85
# 196  SOUTH ANDAMANS            Rabi         0.50
# 197  SOUTH ANDAMANS            Rabi         235.00
# 198  SOUTH ANDAMANS            Rabi         105.00
# 199  SOUTH ANDAMANS            Rabi         15.05
# 200  SOUTH ANDAMANS            Whole Year   5517.00
# 201  SOUTH ANDAMANS            Whole Year   11000000.00
# 202  SOUTH ANDAMANS            Whole Year   220.00
# 203  ANANTAPUR                 Kharif       2600.00
# 204  ANANTAPUR                 Kharif       500.00
# 205  ANANTAPUR                 Kharif       100.00
# 206  ANANTAPUR                 Kharif       9400.00
# 207  ANANTAPUR                 Kharif       7100.00
# 208  ANANTAPUR                 Kharif       228400.00
# 209  ANANTAPUR                 Kharif       1000.00
# 210  ANANTAPUR                 Kharif       10200.00
# 211  ANANTAPUR                 Kharif       700.00
# 212  ANANTAPUR                 Kharif       4900.00
# 213  ANANTAPUR                 Kharif       500.00
# 214  ANANTAPUR                 Kharif       100.00
# 215  ANANTAPUR                 Kharif       11800.00
# 216  ANANTAPUR                 Kharif       75400.00
# 217  ANANTAPUR                 Kharif       72900.00
# 218  ANANTAPUR                 Kharif       11100.00
# 219  ANANTAPUR                 Kharif       200.00
# 220  ANANTAPUR                 Rabi         100.00
# 221  ANANTAPUR                 Rabi         14800.00
# 222  ANANTAPUR                 Rabi         21700.00
# 223  ANANTAPUR                 Rabi         200.00
# 224  ANANTAPUR                 Rabi         9400.00
# 225  ANANTAPUR                 Rabi         100.00
# 226  ANANTAPUR                 Rabi         2400.00
# 227  ANANTAPUR                 Rabi         1000.00
# 228  ANANTAPUR                 Rabi         37300.00
# 229  ANANTAPUR                 Rabi         11100.00
# 230  ANANTAPUR                 Rabi         200.00
# 231  ANANTAPUR                 Kharif       9100.00
# 232  ANANTAPUR                 Kharif       1900.00
# 233  ANANTAPUR                 Kharif       1000.00
# 234  ANANTAPUR                 Kharif       12900.00
# 235  ANANTAPUR                 Kharif       10000.00
# 236  ANANTAPUR                 Kharif       867800.00
# 237  ANANTAPUR                 Kharif       900.00
# 238  ANANTAPUR                 Kharif       5800.00
# 239  ANANTAPUR                 Kharif       3400.00
# 240  ANANTAPUR                 Kharif       6700.00
# 241  ANANTAPUR                 Kharif       1300.00
# 242  ANANTAPUR                 Kharif       300.00
# 243  ANANTAPUR                 Kharif       14900.00
# 244  ANANTAPUR                 Kharif       96800.00
# 245  ANANTAPUR                 Kharif       12200.00
# 246  ANANTAPUR                 Rabi         200.00
# 247  ANANTAPUR                 Rabi         25900.00
# 248  ANANTAPUR                 Rabi         35800.00
# 249  ANANTAPUR                 Rabi         500.00
# 250  ANANTAPUR                 Rabi         22100.00
# 251  ANANTAPUR                 Rabi         1600.00
# 252  ANANTAPUR                 Rabi         1200.00
# 253  ANANTAPUR                 Rabi         63900.00
# 254  ANANTAPUR                 Rabi         3300.00
# 255  ANANTAPUR                 Rabi         200.00
# 256  ANANTAPUR                 Whole Year   65900.00
# 257  ANANTAPUR                 Whole Year   100.00
# 258  ANANTAPUR                 Kharif       889.00
# 259  ANANTAPUR                 Kharif       355.00
# 260  ANANTAPUR                 Kharif       10510.00
# 261  ANANTAPUR                 Kharif       249457.00
# 262  ANANTAPUR                 Kharif       495.00
# 263  ANANTAPUR                 Kharif       14582.00
# 264  ANANTAPUR                 Kharif       9540.00
# 265  ANANTAPUR                 Kharif       3861.00
# 266  ANANTAPUR                 Kharif       1098.00
# 267  ANANTAPUR                 Kharif       11467.00
# 268  ANANTAPUR                 Kharif       105082.00
# 269  ANANTAPUR                 Kharif       2.00
# 270  ANANTAPUR                 Kharif       2.00
# 271  ANANTAPUR                 Rabi         54.00
# 272  ANANTAPUR                 Rabi         9365.00
# 273  ANANTAPUR                 Rabi         25358.00
# 274  ANANTAPUR                 Rabi         327.00
# 275  ANANTAPUR                 Rabi         30576.00
# 276  ANANTAPUR                 Rabi         1.00
# 277  ANANTAPUR                 Rabi         2203.00
# 278  ANANTAPUR                 Rabi         10.00
# 279  ANANTAPUR                 Rabi         1.00
# 280  ANANTAPUR                 Rabi         1180.00
# 281  ANANTAPUR                 Rabi         45669.00
# 282  ANANTAPUR                 Rabi         145.00
# 283  ANANTAPUR                 Rabi         2.00
# 284  ANANTAPUR                 Rabi         294.00
# 285  ANANTAPUR                 Whole Year   5759.00
# 286  ANANTAPUR                 Whole Year   32364.00
# 287  ANANTAPUR                 Whole Year   83126.00
# 288  ANANTAPUR                 Kharif       7888.00
# 289  ANANTAPUR                 Kharif       1449.00
# 290  ANANTAPUR                 Kharif       2831.00
# 291  ANANTAPUR                 Kharif       16128.00
# 292  ANANTAPUR                 Kharif       10146.00
# 293  ANANTAPUR                 Kharif       14.00
# 294  ANANTAPUR                 Kharif       884963.00
# 295  ANANTAPUR                 Kharif       215.00
# 296  ANANTAPUR                 Kharif       14351.00
# 297  ANANTAPUR                 Kharif       1143.00
# 298  ANANTAPUR                 Kharif       9049.00
# do you want to search for specific details?yes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-6514bf4f4e59> in <module>()
#     104       if ans == 'yes':
#     105             cropdata.reset_index(drop=True)
# --> 106             year = int(input("Enter the year: "))
#     107             print(cropdata.loc[cropdata['Crop_Year'] == year]['Crop'])
#     108             crop = input("Enter the crop name: ")
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:
